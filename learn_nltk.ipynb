# %%
import os
import nltk
# nltk.download('stopwords')
import nltk.corpus

# %%
os.listdir(nltk.data.find("corpora"))
# Out:
# ['stopwords', 'stopwords.zip']

# %%
nltk.download()

# %%
pip install --upgrade certifi

# %%
pip install --upgrade nltk

# %%
import nltk
import ssl
import certifi

ssl._create_default_https_context = ssl.create_default_context
ssl._create_default_https_context().load_verify_locations(certifi.where())
nltk.download()

# %%
# alretnative download by disabilting ssl verification

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import nltk
nltk.download()

# %%
# implement tfidf vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
tfidf_v = TfidfVectorizer()
count_c = CountVectorizer()
tfidf_v, count_c
# Out:
# (TfidfVectorizer(), CountVectorizer())

# %%
# sample_text = "The Student Scholarship portal opened on January 15, 2025! Each year, ETS provides scholarships to create college access for disadvantaged students and recognize their academic achievement. These scholarships directly impact undergraduate and graduate students based on the criteria they represent."
# sample_text
# Out:
# 'The Student Scholarship portal opened on January 15, 2025! Each year, ETS provides scholarships to create college access for disadvantaged students and recognize their academic achievement. These scholarships directly impact undergraduate and graduate students based on the criteria they represent.'

# %%
import sklearn
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression()
model_lr
# Out:
# LogisticRegression()

# %%
# dir(sklearn.linear_model)
dir(sklearn.svm)
# Out:
# ['LinearSVC',
#  'LinearSVR',
#  'NuSVC',
#  'NuSVR',
#  'OneClassSVM',
#  'SVC',
#  'SVR',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_base',
#  '_bounds',
#  '_classes',
#  '_liblinear',
#  '_libsvm',
#  '_libsvm_sparse',
#  'l1_min_c']

# %%
# Things need to know about sklearn

# 1. sklearn.linear_models
# 2. sklearn.svm
# 3. sklearn.tree
# 4. sklearn.neighbors
# 4. sklearn.navie_bayes
# 4. sklearn.neural_network
# 4. sklearn.cluster

# 5. sklearn.metrics

# 6. sklearn.feature_selection (SelectKBest)
# 7. sklearn.feature_extraction (text.TfidfVectorizer)
# 8. sklearn.model_selection (train_test_split, HyperParameterTuning, KFold)
# 9. sklearn.preprocessing (StandardScalar, MaxMinScalar)

# %%
from sklearn.pipeline import Pipeline

# %%
dir(sklearn.pipeline)
# Out:
# ['Bunch',
#  'Counter',
#  'FeatureUnion',
#  'FunctionTransformer',
#  'HasMethods',
#  'Hidden',
#  'METHODS',
#  'MetadataRouter',
#  'MethodMapping',
#  'NotFittedError',
#  'Parallel',
#  'Pipeline',
#  'TransformerMixin',
#  '_BaseComposition',
#  '_VisualBlock',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_deprecate_Xt_in_inverse_transform',
#  '_final_estimator_has',
#  '_fit_context',
#  '_fit_one',
#  '_fit_transform_one',
#  '_get_container_adapter',
#  '_name_estimators',
#  '_print_elapsed_time',
#  '_raise_for_params',
#  '_routing_enabled',
#  '_safe_set_output',
#  '_safe_tags',
#  '_transform_one',
#  'available_if',
#  'chain',
#  'check_is_fitted',
#  'check_memory',
#  'clone',
#  'defaultdict',
#  'delayed',
#  'islice',
#  'make_pipeline',
#  'make_union',
#  'np',
#  'process_routing',
#  'sparse']

# %%
from keras.models import Sequential
Sequential()
# from tensorflow.keras.models import Sequential

# %%
import torch
if torch.backends.mps.is_available():
    print(torch.cuda.device_count())
# Out:
# 0

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
pip install torch --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
torch.__version__
# Out:
# '2.5.1'
